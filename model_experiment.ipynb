# %%
import mlflow
import os

os.environ["MLFLOW_TRACKING_USERNAME"] = "sophyrise"
os.environ["MLFLOW_TRACKING_PASSWORD"] = "95f86824d28eb66b760d891dfa5f39816ddea9c4"

mlflow.set_tracking_uri("https://dagshub.com/sophyrise/house-prices-mlflow.mlflow")
mlflow.set_experiment("house-prices")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/a4a47a3ff9434d5facc5125ff435d61a', creation_time=1774786882716, experiment_id='0', last_update_time=1774786882716, lifecycle_stage='active', name='house-prices', tags={}, workspace='default'>
